# %%
import sys
sys.path.append("./src/")
import utils as src_utils

# %%
experiment_dir = "./experiments/baseline"
args = {'--experiment_dir': experiment_dir,
        '--print_every':1,
        '--num_epochs':20,
        '--save_every':1,
        '--data_path':'./data/patches/',
        '--batch_size':96,
        '--model_save_path': experiment_dir + "/model.pt",
        '--n': 24000,
        '--test_split': 0.1,
        '--val_split':0.1,
        '--train_split':0.8,
        '--train_img_directory':experiment_dir + '/images/train_images/',
        '--test_img_directory': experiment_dir + '/images/test_images/',
        '--noise_type': 'gaussian'
        }
# To retrain uncomment these lines 

###################################
# train_losses,train_PSNRs,val_losses,val_PSNRs,best_val_PSNR = train(args)
# np.save(experiment_dir + '/train_PSNRs.npy', np.array(train_PSNRs))
# np.save(experiment_dir + '/train_losses.npy', np.array(train_losses))
# np.save(experiment_dir + '/val_PSNRs.npy', np.array(val_PSNRs))
# np.save(experiment_dir + '/val_losses.npy', np.array(val_losses))

# loss = train_losses[-1]
# print("Final training loss: {}, Best Validation PSNR: {}".format(loss, best_val_PSNR))

###################################

test_loss,test_PSNR,test_SSIM = src_utils.Test(args)
print("Test loss: {}, Test PSNR: {}, Test SSIM: {}".format(test_loss, test_PSNR,test_SSIM))
# Out:
# loading patches from patches directory
# (240, 240)
# 100%|██████████| 24000/24000 [01:03<00:00, 377.67it/s]
# completed loading patches from directory!
# (24000, 240, 240)
# noise_type:  gaussian
# shape of target: (24000, 1, 240, 240) shape of noisy: (24000, 1, 240, 240)
#   0%|          | 0/25 [00:00<?, ?it/s]
# channel_1: 16, channel_2: 32
# Loading model from ./experiments/baseline/model.pt
# Model successfully loaded from ./experiments/baseline/model.pt
# Testing...
#  96%|█████████▌| 24/25 [03:43<00:09,  9.23s/it]
# test images
# Input
# Output
# Real
# 100%|██████████| 25/25 [03:57<00:00, 10.67s/it]
# Images saved to ./experiments/baseline/images/test_images/
# Test loss: 0.0015686952974647284, Test PSNR: 28.061782374120902, Test SSIM: 0.853613973888868

# %%
experiment_dir = "./experiments/mixture"
args = {'--experiment_dir': experiment_dir,
        '--print_every':1,
        '--num_epochs':20,
        '--save_every':1,
        '--data_path':'./data/patches/',
        '--batch_size':96,
        '--model_save_path': experiment_dir + "/model.pt",
        '--n': 24000,
        '--test_split': 0.1,
        '--val_split':0.1,
        '--train_split':0.8,
        '--train_img_directory':experiment_dir + '/images/train_images/',
        '--test_img_directory': experiment_dir + '/images/test_images/',
        '--noise_type': 'mixture'
        }
# To retrain uncomment these lines 

###################################
# train_losses,train_PSNRs,val_losses,val_PSNRs,best_val_PSNR = train(args)
# np.save(experiment_dir + '/train_PSNRs.npy', np.array(train_PSNRs))
# np.save(experiment_dir + '/train_losses.npy', np.array(train_losses))
# np.save(experiment_dir + '/val_PSNRs.npy', np.array(val_PSNRs))
# np.save(experiment_dir + '/val_losses.npy', np.array(val_losses))

# loss = train_losses[-1]
# print("Final training loss: {}, Best Validation PSNR: {}".format(loss, best_val_PSNR))

###################################

test_loss,test_PSNR,test_SSIM = src_utils.Test(args)
print("Test loss: {}, Test PSNR: {}, Test SSIM: {}".format(test_loss, test_PSNR,test_SSIM))
# Out:
# loading patches from patches directory
# (240, 240)
# 100%|██████████| 24000/24000 [01:08<00:00, 350.29it/s]
# completed loading patches from directory!
# (24000, 240, 240)
# noise_type:  mixture
# shape of target: (24000, 1, 240, 240) shape of noisy: (24000, 1, 240, 240)
# channel_1: 16, channel_2: 32
#   0%|          | 0/25 [00:00<?, ?it/s]
# Loading model from ./experiments/mixture/model.pt
# Model successfully loaded from ./experiments/mixture/model.pt
# Testing...
#  96%|█████████▌| 24/25 [03:48<00:09,  9.51s/it]
# test images
# Input
# Output
# Real
# 100%|██████████| 25/25 [04:02<00:00, 10.94s/it]
# Images saved to ./experiments/mixture/images/test_images/
# Test loss: 0.0011983338044956326, Test PSNR: 29.232228766892796, Test SSIM: 0.8597947146219143

# %%
experiment_dir = "./experiments/s_p"
args = {'--experiment_dir': experiment_dir,
        '--print_every':1,
        '--num_epochs':20,
        '--save_every':1,
        '--data_path':'./data/patches/',
        '--batch_size':96,
        '--model_save_path': experiment_dir + "/model.pt",
        '--n': 24000,
        '--test_split': 0.1,
        '--val_split':0.1,
        '--train_split':0.8,
        '--train_img_directory':experiment_dir + '/images/train_images/',
        '--test_img_directory': experiment_dir + '/images/test_images/',
        '--noise_type': 's&p'
        }
# To retrain uncomment these lines 

###################################
# train_losses,train_PSNRs,val_losses,val_PSNRs,best_val_PSNR = train(args)
# np.save(experiment_dir + '/train_PSNRs.npy', np.array(train_PSNRs))
# np.save(experiment_dir + '/train_losses.npy', np.array(train_losses))
# np.save(experiment_dir + '/val_PSNRs.npy', np.array(val_PSNRs))
# np.save(experiment_dir + '/val_losses.npy', np.array(val_losses))

# loss = train_losses[-1]
# print("Final training loss: {}, Best Validation PSNR: {}".format(loss, best_val_PSNR))

###################################

test_loss,test_PSNR,test_SSIM = src_Test(args)
print("Test loss: {}, Test PSNR: {}, Test SSIM: {}".format(test_loss, test_PSNR,test_SSIM))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ab995329b13b> in <module>
#      29 ###################################
#      30
# ---> 31 test_loss,test_PSNR,test_SSIM = src_Test(args)
#      32 print("Test loss: {}, Test PSNR: {}, Test SSIM: {}".format(test_loss, test_PSNR,test_SSIM))
#
# NameError: name 'src_Test' is not defined
